# %%
from urllib.request import Request, urlopen, HTTPError
import os
import json
from multiprocessing import Process, Array
import sys
import requests
import pandas as pd
import numpy as np

## to find this, right click and 'inspect element' on the workday page in your browser. from there, navigate to the network tab
## and ctrl + r to refresh the page. you should see a whole bunch of requests come in. sort by Fetch/XHR and click through them until you see one 
## that has a Request Method: of POST instead of GET and it has a request URL and payload that makes sense
POST_url = "https://gsk.wd5.myworkdayjobs.com/wday/cxs/gsk/GSKCareers/jobs"
ind_job_url = "https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/"
payload = {"appliedFacets": {}, "limit": 20, "offset": 0, "searchText": ""}


url = POST_url
payload = payload
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0"
    }

r = requests.post(url, json=payload, headers=headers)

offsets = np.arange(0, r.json()['total'], 20)
jobs = []

titles = []
location = []
postedOn = []
externalURL = []


for offset in offsets:
    
    url = POST_url
    payload['offset'] = float(offset)
    payload = payload
    headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0"
    }
    
    
    r = requests.post(url, json=payload, headers=headers)
    data = r.json()
    for job in data["jobPostings"]:
        titles = np.append(titles, job.get('title'))
        location = np.append(location, job.get("locationsText", ""))
        postedOn = np.append(postedOn, job.get('postedOn'))

        try:
            externalURL = np.append(externalURL, ind_job_url+ job['externalPath'].split('/')[-1])
        except:
            externalURL = np.append(externalURL, 'not avail')

        # jobs.append({
        #     "title": job.get("title"),
        #     "location": job.get("locationsText", ""),
        #     "postedOn": job.get("postedOn", "")
        #     })
    

pd.set_option('display.max_colwidth', 800)
jobs_dict = dict(zip(['location', 'postedOn', 'titles', 'externalURL'], [location, postedOn, titles, externalURL]))
df = pd.DataFrame(jobs_dict)
posted_recently = df[df["postedOn"].str.contains('Posted Today|Posted Yesterday', case=False, na=False)]
location = posted_recently[posted_recently["location"].str.contains('Pennsylvania|North Carolina|Locations', case=False, na=False)]

# %%
location
# Out:
#                           location          postedOn  \
# 0                      4 Locations      Posted Today
# 2   USA - North Carolina - Zebulon      Posted Today
# 3                      2 Locations      Posted Today
# 5                      9 Locations      Posted Today
# 9                      2 Locations      Posted Today
# 12                     3 Locations      Posted Today
# 22                     5 Locations      Posted Today
# 32  USA - North Carolina - Raleigh  Posted Yesterday
# 33                     3 Locations  Posted Yesterday
# 34                     2 Locations  Posted Yesterday
# 36                     2 Locations  Posted Yesterday
# 39                     2 Locations  Posted Yesterday
# 47                     2 Locations  Posted Yesterday
#
#                                                                                                            titles  \
# 0                                                                 Clinical Development Medical Director- Vascular
# 2                                                                                           QC Laboratory Manager
# 3                                                             Clinical Development Medical Director- Inflammation
# 5                                                   Key Account Manager - Haematology (Wessex, Surrey and Sussex)
# 9                                                                           Regional Business Manager Norte - VIH
# 12                                                                                         Senior Program Manager
# 22                                                                       Director Clinical Pharmacology MIDD Lead
# 32                                                                   Territory Account Manager, ViiV- Raleigh, NC
# 33                ViiV Healthcare (GSK) Regional Sales Director, Pacific Region (CA, OR, WA and AK) - Field Based
# 34                                                                                             Technical Director
# 36                                                                                              Data Architect II
# 39                                         Director, Market Access Strategy, Access Optimization Lead – Specialty
# 47  Senior Regulatory Specialist, Small Molecules Mature Products, CMC, Global Regulatory Affairs – Delivery Team
#
#                                                                                                                                                                       externalURL
# 0                                                                   https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Clinical-Development-Medical-Director--Vascular_430748
# 2                                                                                             https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/QC-Laboratory-Manager_429434
# 3                                                https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Clinical-Development-Medical-Director--Inflammation-and-Fibrosis_430387-1
# 5                                                   https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Key-Account-Manager---Haematology--Wessex--Surrey-and-Sussex-_432275-1
# 9                                                                           https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Regional-Business-Manager-Norte---VIH_432330-2
# 12                                                                                           https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Senior-Program-Manager_431247
# 22                                                                       https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Director-Clinical-Pharmacology-MIDD-Lead_432209-1
# 32                                                                   https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Territory-Account-Manager--ViiV--Raleigh--NC_431111-1
# 33                https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/ViiV-Healthcare--GSK--Regional-Sales-Director--Pacific-Region--CA--OR--WA-and-AK----Field-Based_432289-1
# 34                                                                                             https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Technical-Director_431481-2
# 36                                                                                                https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Data-Architect-II_431270
# 39                                           https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Director--Market-Access-Strategy--Access-Optimization-Lead---Specialty_432293
# 47  https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Senior-Regulatory-Specialist--Small-Molecules-Mature-Products--CMC--Global-Regulatory-Affairs---Delivery-Team_432222-1

# %%
from urllib.request import Request, urlopen, HTTPError
import os
import json
from multiprocessing import Process, Array
import sys
#import util
import requests
import pandas as pd

# %%
## to find this, right click and 'inspect element' on the workday page in your browser. from there, navigate to the network tab
## and ctrl + r to refresh the page. you should see a whole bunch of requests come in. sort by Fetch/XHR and click through them until you see one 
## that has a Request Method: of POST instead of GET and it has a request URL and payload that makes sense
POST_url = "https://gsk.wd5.myworkdayjobs.com/wday/cxs/gsk/GSKCareers/jobs"
ind_job_url = "https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/"
payload = {"appliedFacets": {}, "limit": 20, "offset": 0, "searchText": ""}

# %%
url = POST_url
payload = payload
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0"
}

r = requests.post(url, json=payload, headers=headers)

# %%
import numpy as np

offsets = np.arange(0, r.json()['total'], 20)
jobs = []
for offset in offsets:
    
    url = POST_url
    payload['offset'] = float(offset)
    payload = payload
    headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0"
    }
    
    
    r = requests.post(url, json=payload, headers=headers)
    data = r.json()

    title = []
    location = []
    postedOn = []
    url = []
    
    for job in data['jobPostings']:
        title = np.append(title, job.get("title"))
        location = np.append(location, job.get("location"))
        postedOn = np.append(postedOn, job.get("postedOn"))
        # try:
        #     url = np.append(url, ind_job_url+job.get("externalPath").split('/')[-1])
        # except:
        #     url = np.append(url, 'externalpathnotavail')

    # for job in data["jobPostings"]:
    #     jobs.append({
    #         "title": job.get("title"),
    #         "location": job.get("locationsText", ""),
    #         "postedOn": job.get("postedOn", ""),
    #         "url": ind_job_url+ job['externalPath'].split('/')[-1]
    #         })

# %%
r.json()
# Out:
# {'total': 0,
#  'jobPostings': [{'title': 'Practicante Tecnologia',
#    'externalPath': '/job/Colombia---Capital-District---Bogota/Practicante-Tecnologia_335821-1',
#    'locationsText': 'Colombia - Capital District - Bogota',
#    'postedOn': 'Posted 30+ Days Ago',
#    'bulletFields': ['335821']},
#   {'title': 'Senior Executive Medical Representative',
#    'externalPath': '/job/China---Guangdong---Chaozhou/Senior-Executive-Medical-Representative_334175-1',
#    'locationsText': 'China - Guangdong - Chaozhou',
#    'postedOn': 'Posted 30+ Days Ago'}],
#  'facets': [],
#  'userAuthenticated': False}

# %%
job.get('title')
# Out:
# 'Senior Executive Medical Representative'

# %%
pd.set_option('display.max_colwidth', 800)
df = pd.DataFrame(jobs)
posted_recently = df[df["postedOn"].str.contains('Posted Today|Posted Yesterday', case=False, na=False)]
location = posted_recently[posted_recently["location"].str.contains('Pennsylvania|North Carolina|Locations', case=False, na=False)]

# %%
df
# Out:
#                                                              title  \
# 0    Key Account Manager - Haematology (Wessex, Surrey and Sussex)
# 1                                              Material Technician
# 2                                 Operational Quality (OQ) Manager
# 3     GESTIONNAIRE ACHATS H/F (Mission ou CDD jusqu'au 31/03/2027)
# 4                            Regional Business Manager Norte - VIH
# ..                                                             ...
# 582        Senior Reporting Specialist  - General Application Form
# 583                Financial Controller - General Application Form
# 584                    Medical Business Associate - Women in Sales
# 585                                         Practicante Tecnologia
# 586                        Senior Executive Medical Representative
#
#                                  location             postedOn  \
# 0                             9 Locations         Posted Today
# 1              USA - Maryland - Rockville         Posted Today
# 2     UK - County Durham - Barnard Castle         Posted Today
# 3                         France - Evreux         Posted Today
# 4                             2 Locations         Posted Today
# ..                                    ...                  ...
# 582                Poznan Business Garden  Posted 30+ Days Ago
# 583                Poznan Business Garden  Posted 30+ Days Ago
# 584                 Field Worker - IND Rx  Posted 30+ Days Ago
# 585  Colombia - Capital District - Bogota  Posted 30+ Days Ago
# 586          China - Guangdong - Chaozhou  Posted 30+ Days Ago
#
#                                                                                                                                url
# 0    https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Key-Account-Manager---Haematology--Wessex--Surrey-and-Sussex-_432275-1
# 1                                              https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Material-Technician_432278-1
# 2                                 https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Operational-Quality--OQ--Manager_429101-1
# 3                https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/GESTIONNAIRE-ACHATS-H-F--CDD-jusqu-au-31-03-2027-_432496-1
# 4                            https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Regional-Business-Manager-Norte---VIH_432330-2
# ..                                                                                                                             ...
# 582                   https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Finance-Reporting---General-Application-Form_352331-1
# 583                 https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Finance-Controlling---General-Application-Form_352333-1
# 584                      https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Medical-Business-Associate---Women-in-Sales_367465
# 585                                         https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Practicante-Tecnologia_335821-1
# 586                        https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Senior-Executive-Medical-Representative_334175-1
#
# [587 rows x 4 columns]

# %%
location
# Out:
#                                                                                                             title  \
# 0                                                   Key Account Manager - Haematology (Wessex, Surrey and Sussex)
# 4                                                                           Regional Business Manager Norte - VIH
# 7                                                                                          Senior Program Manager
# 17                                                                       Director Clinical Pharmacology MIDD Lead
# 29                                                                   Territory Account Manager, ViiV- Raleigh, NC
# 30                ViiV Healthcare (GSK) Regional Sales Director, Pacific Region (CA, OR, WA and AK) - Field Based
# 31                                                                                             Technical Director
# 33                                                                                              Data Architect II
# 37                                         Director, Market Access Strategy, Access Optimization Lead – Specialty
# 45  Senior Regulatory Specialist, Small Molecules Mature Products, CMC, Global Regulatory Affairs – Delivery Team
#
#                           location          postedOn  \
# 0                      9 Locations      Posted Today
# 4                      2 Locations      Posted Today
# 7                      3 Locations      Posted Today
# 17                     5 Locations      Posted Today
# 29  USA - North Carolina - Raleigh  Posted Yesterday
# 30                     3 Locations  Posted Yesterday
# 31                     2 Locations  Posted Yesterday
# 33                     2 Locations  Posted Yesterday
# 37                     2 Locations  Posted Yesterday
# 45                     2 Locations  Posted Yesterday
#
#                                                                                                                                                                               url
# 0                                                   https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Key-Account-Manager---Haematology--Wessex--Surrey-and-Sussex-_432275-1
# 4                                                                           https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Regional-Business-Manager-Norte---VIH_432330-2
# 7                                                                                            https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Senior-Program-Manager_431247
# 17                                                                       https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Director-Clinical-Pharmacology-MIDD-Lead_432209-1
# 29                                                                   https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Territory-Account-Manager--ViiV--Raleigh--NC_431111-1
# 30                https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/ViiV-Healthcare--GSK--Regional-Sales-Director--Pacific-Region--CA--OR--WA-and-AK----Field-Based_432289-1
# 31                                                                                             https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Technical-Director_431481-2
# 33                                                                                                https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Data-Architect-II_431270
# 37                                           https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Director--Market-Access-Strategy--Access-Optimization-Lead---Specialty_432293
# 45  https://gsk.wd5.myworkdayjobs.com/en-US/GSKCareers/job/Senior-Regulatory-Specialist--Small-Molecules-Mature-Products--CMC--Global-Regulatory-Affairs---Delivery-Team_432222-1

# %%
location.to_csv(os.path.join(os.getcwd(),'jobs_update.csv'))

# %%
from urllib.request import Request, urlopen, HTTPError
import os
import json
from multiprocessing import Process, Array
import sys
import util
import requests
import pandas as pd
import numpy as np

## to find this, right click and 'inspect element' on the workday page in your browser. from there, navigate to the network tab
## and ctrl + r to refresh the page. you should see a whole bunch of requests come in. sort by Fetch/XHR and click through them until you see one 
## that has a Request Method: of POST instead of GET and it has a request URL and payload that makes sense
POST_url = "https://msd.wd5.myworkdayjobs.com/wday/cxs/msd/SearchJobs/jobs"
ind_job_url = "https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/"
payload = {"appliedFacets": {}, "limit": 20, "offset": 20, "searchText": ""}


def today_jobs(POST_url, ind_job_url,payload):

    url = POST_url
    payload = payload
    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json",
        "User-Agent": "Mozilla/5.0"
    }

    r = requests.post(url, json=payload, headers=headers)

    offsets = np.arange(0, r.json()['total'], 20)
    jobs = []
    for offset in offsets:
        
        url = POST_url
        payload['offset'] = float(offset)
        payload = payload
        headers = {
        "Content-Type": "application/json",
        "Accept": "application/json",
        "User-Agent": "Mozilla/5.0"
        }
        
        
        r = requests.post(url, json=payload, headers=headers)
        data = r.json()
        for job in data["jobPostings"]:
            jobs.append({
                "title": job.get("title"),
                "location": job.get("locationsText", ""),
                "postedOn": job.get("postedOn", ""),
                "url": ind_job_url+ job['externalPath'].split('/')[-1]
                })
        

    pd.set_option('display.max_colwidth', 800)
    df = pd.DataFrame(jobs)
    posted_recently = df[df["postedOn"].str.contains('Posted Today|Posted Yesterday', case=False, na=False)]
    location = posted_recently[posted_recently["location"].str.contains('USA - Pennsylvania|USA - North Carolina|Location|USA - REMOTE', case=False, na=False)]
    return location
    location.to_csv('jobs_update.csv')

# %%
POST_url = "https://msd.wd5.myworkdayjobs.com/wday/cxs/msd/SearchJobs/jobs"
ind_job_url = "https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/"
payload = {"appliedFacets": {}, "limit": 20, "offset": 20, "searchText": ""}
today_jobs(POST_url,ind_job_url, payload)
# Out:
#                                                                                                              title  \
# 0                                                           Director, Engineering - Drug Product Commercialization
# 3                                                                                      Assoc. II, Customer Support
# 6                                                                           Senior Specialist - Regulatory Affairs
# 7                                                                                              Spclst, Engineering
# 8                                                                                                Spclst, Logistics
# 13                               2026 Future Talent Program - Animal Health Research & Development Summer - Intern
# 15                                                    2026 Future Talent Program - Beef Cattle Monitoring - Intern
# 19                                         2026 Future Talent Program – Dairy Monitoring Customer Success – Intern
# 22                                                                  2026 Future Talent Program - Marketing - Co-op
# 24                                                                                     Chief of Staff and PMO Lead
# 26                                                                      Dir, Engineering, CMC Leader for Biologics
# 32                                                    Senior Scientist, Clinical Operations - Senior Study Manager
# 35                                                                           Financial Planning & Analysis Manager
# 48                                                                                        Hatchery Device Engineer
# 50                                                                                            Marketing Specialist
# 61                                                                             Dir. , Technical Product Management
# 66                                                    Senior Statistical Programmer- Analysis & Reporting - Hybrid
# 67                                                                  Vaccines Customer Representative - Buffalo, NY
# 68                2026 Future Talent Program - Discovery Oncology - Intern (South San Francisco, CA or Boston, MA)
# 70   GYN Oncology, Regional Medical Scientific Director - Midwest: MN, WI, ND, SD, IA, KS, NE, IN, MI(UP) (Remote)
# 73                                                                Senior Scientist, Statistical Programmer- Hybrid
# 76                 2026 Future Talent Program - Discovery Oncology - Co-op (South San Francisco, CA or Boston, MA)
# 79                                           Companion Animal Senior Territory Representative -  (Charlotte North)
# 81                                                                  Senior Scientist, Vaccine Discovery (Virology)
# 82                                                                Senior Specialist, Stability Operations - Hybrid
# 83                                                                Associate Director, US Customer Segment Strategy
# 84                                                                      Associate Director, Production Maintenance
# 85                                                      Associate Scientist, Post Doctoral Fellow, Neuroimmunology
# 90                     Associate Principal Scientist/Engineer, Medical Device and Combination Products, Analytical
# 96                                                                              Farm Consultant (m/w/d) Region Ost
# 102                                                                Manager, M365 Exchange Online / Exchange Server
# 115                                                                                 Spclst , Technology Compliance
# 117                                               Senior Data Engineer, Process R&D Enabling Technologies (Hybrid)
#
#                                                                location  \
# 0                                       USA - Pennsylvania - West Point
# 3                                                           2 Locations
# 6                                                           2 Locations
# 7                                       USA - Pennsylvania - West Point
# 8    USA - Pennsylvania - North Wales (Wissahickon Ave 140 NW3 and NW4)
# 13                                                          2 Locations
# 15                                                          4 Locations
# 19                                                          4 Locations
# 22                                                          2 Locations
# 24                                                          2 Locations
# 26                                                          2 Locations
# 32                                                          2 Locations
# 35                                                          7 Locations
# 48                                                          2 Locations
# 50                                                          2 Locations
# 61                                                          3 Locations
# 66                                                          2 Locations
# 67                                                          2 Locations
# 68                                                          2 Locations
# 70                                                          7 Locations
# 73                                                          2 Locations
# 76                                                          2 Locations
# 79                                                          2 Locations
# 81                                      USA - Pennsylvania - West Point
# 82                                                          2 Locations
# 83                     USA - Pennsylvania - North Wales (Upper Gwynedd)
# 84                                        USA - North Carolina - Wilson
# 85                                      USA - Pennsylvania - West Point
# 90                                      USA - Pennsylvania - West Point
# 96                                                          3 Locations
# 102                                                         2 Locations
# 115                                                         2 Locations
# 117                                                         2 Locations
#
#              postedOn  \
# 0    Posted Yesterday
# 3        Posted Today
# 6        Posted Today
# 7        Posted Today
# 8        Posted Today
# 13       Posted Today
# 15       Posted Today
# 19       Posted Today
# 22       Posted Today
# 24       Posted Today
# 26       Posted Today
# 32       Posted Today
# 35       Posted Today
# 48       Posted Today
# 50       Posted Today
# 61   Posted Yesterday
# 66   Posted Yesterday
# 67   Posted Yesterday
# 68   Posted Yesterday
# 70   Posted Yesterday
# 73   Posted Yesterday
# 73                                                                https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Senior-Scientist--Statistical-Programmer--Hybrid_R367015-1
# 76                                                   https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/XMLNAME-2026-Future-Talent-Program---Discovery-Oncology---Co-op_R361226
# 79                                           https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Companion-Animal-Senior-Territory-Representative-----Charlotte-North-_R372958-1
# 81                                                                  https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Senior-Scientist--Vaccine-Discovery--Virology-_R372488-1
# 82                                                                https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Senior-Specialist--Stability-Operations---Hybrid_R372374-1
# 83                                                                https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Associate-Director--US-Customer-Segment-Strategy_R372478-1
# 84                                                                      https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Associate-Director--Production-Maintenance_R372728-1
# 85                                                      https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Associate-Scientist--Post-Doctoral-Fellow--Neuroimmunology_R370877-1
# 90                     https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Associate-Principal-Scientist-Engineer--Medical-Device-and-Combination-Products--Analytical_R365159-1
# 96                                                                                https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Farm-Consultant--m-w-d--Region-Ost_R370755
# 102                                                                https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Manager--M365-Exchange-Online---Exchange-Server_R370661-1
# 115                                                                                 https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Spclst---Technology-Compliance_R372044-1
# 117                                                 https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Senior-Data-Engineer--Process-R-D-Enabling-Technologies--Hybrid-_R370265

# %%
import smtplib
from email.message import EmailMessage
from datetime import datetime

def send_email_report(df):
    if df.empty:
        body = "No new job postings today."
    else:
        body = f"{len(df)} new job(s) posted today:\n\n" + "\n".join(df['title'].tolist())

    msg = EmailMessage()
    msg['Subject'] = f"Merck Workday Jobs Report – {datetime.now().strftime('%Y-%m-%d')}"
    msg['From'] = 'bdev1238@gmail.com'
    msg['To'] = "bdev1238@gmail.com"
    msg.set_content(body)

    # Attach CSV if there are new postings
    if not df.empty:
        csv_data = df.to_csv(index=False)
        msg.add_attachment(csv_data, filename="workday_jobs_today.csv", subtype="csv")

    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as smtp:
        smtp.login('bdev1238@gmail.com', 'macw dblk fqmc qldy')
        smtp.send_message(msg)

# Call this after your DataFrame is ready:
send_email_report(today_jobs(POST_url,ind_job_url, payload))

# %%
df
# Out:
#                                                                          title  \
# 0                       Director, Engineering - Drug Product Commercialization
# 1                                          Principal Scientist, Drug Discovery
# 2    Associate Principal Scientist, Statistical Programmer | Oncology (Hybrid)
# 3                                               Assoc. Scientist, Pharmacology
# 4                                   Dir, Engineering, CMC Leader for Biologics
# ..                                                                         ...
# 693                           Medical Affairs MSL (Vaccine/Infectious Disease)
# 694                              Data Strategy & Innovation Associate Director
# 695                                    Intern, Utilities Facilities Management
# 696             R&D Oncology Clinical Science, Clinical Research Sr. Scientist
# 697                     Medical Affairs Oncology MSL (Medical Science Liaison)
#
#                                           location             postedOn  \
# 0                  USA - Pennsylvania - West Point     Posted Yesterday
# 1                        USA - New Jersey - Rahway    Posted 2 Days Ago
# 2                                      2 Locations  Posted 30+ Days Ago
# 3                  CHL - Llanquihue - Puerto Varas         Posted Today
# 4                                      2 Locations         Posted Today
# ..                                             ...                  ...
# 693                          JPN - Tokyo - Chiyoda  Posted 30+ Days Ago
# 694                          JPN - Tokyo - Chiyoda  Posted 30+ Days Ago
# 695  SGP - Singapore - Singapore (70 Tuas West Dr)  Posted 30+ Days Ago
# 696                          JPN - Tokyo - Chiyoda  Posted 30+ Days Ago
# 697                          JPN - Tokyo - Chiyoda  Posted 30+ Days Ago
#
#                                                                                                                                                 url
# 0                         https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Director--Engineering---Drug-Product-Commercialization_R357744
# 1                                         https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Principal-Scientist--Biology-Discovery_R363749
# 2    https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Associate-Principal-Scientist--Statistical-Programmer---Oncology--Hybrid-_R306311-1
# 3                                                  https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Assoc-Scientist--Pharmacology_R371502
# 4                                   https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Dir--Engineering--CMC-Leader-for-Biologics_R360437-1
# ..                                                                                                                                              ...
# 693                             https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Medical-Affairs-MSL--Vaccine-Infectious-Disease-_R316253
# 694                                https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Data-Strategy---Innovation-Associate-Director_R353815
# 695                                      https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Intern--Utilities-Facilities-Management_R314257
# 696              https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/R-D-Oncology-Clinical-Science--Clinical-Research-Sr-Scientist_R300369-9
# 697                    https://msd.wd5.myworkdayjobs.com/en-US/SearchJobs/details/Medical-Affairs-Oncology-MSL--Medical-Science-Liaison-_R319508-17
#
# [698 rows x 4 columns]

# %%
from urllib.request import Request, urlopen, HTTPError
import os
import json
from multiprocessing import Process, Array
import sys
import util
import requests
import pandas as pd
import numpy as np

## to find this, right click and 'inspect element' on the workday page in your browser. from there, navigate to the network tab
## and ctrl + r to refresh the page. you should see a whole bunch of requests come in. sort by Fetch/XHR and click through them until you see one 
## that has a Request Method: of POST instead of GET and it has a request URL and payload that makes sense
POST_url = "https://lilly.wd5.myworkdayjobs.com/wday/cxs/lilly/LLY/jobs"
ind_job_url = "https://lilly.wd5.myworkdayjobs.com/en-US/LLY/details/"
payload = {"appliedFacets": {}, "limit": 20, "offset": 0, "searchText": ""}



def today_jobs(POST_url, ind_job_url,payload):

    url = POST_url
    payload = payload
    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json",
        "User-Agent": "Mozilla/5.0"
    }

    r = requests.post(url, json=payload, headers=headers)

    offsets = np.arange(0, r.json()['total'], 20)
    jobs = []
    for offset in offsets:
        
        url = POST_url
        payload['offset'] = float(offset)
        payload = payload
        headers = {
        "Content-Type": "application/json",
        "Accept": "application/json",
        "User-Agent": "Mozilla/5.0"
        }
        
        
        r = requests.post(url, json=payload, headers=headers)
        data = r.json()
        print(r)
        for job in data["jobPostings"]:
            jobs.append({
                "title": job.get("title"),
                "location": job.get("locationsText", ""),
                "postedOn": job.get("postedOn", ""),
                "url": ind_job_url+ job['externalPath'].split('/')[-1]
                })
        

    pd.set_option('display.max_colwidth', 800)
    df = pd.DataFrame(jobs)
    df.to_csv('C:\\Users\\Ben\\Desktop\\WebCrawler\\jobs.csv')
    #posted_recently = df[df["postedOn"].str.contains('Posted Today|Posted Yesterday', case=False, na=False)]
    df.to_csv('jobs.csv')
    location = posted_recently[posted_recently["location"].str.contains('USA - Pennsylvania|USA - North Carolina|Location|USA - REMOTE', case=False, na=False)]
    return location


import smtplib
from email.message import EmailMessage
from datetime import datetime

def send_email_report(df):
    if df.empty:
        body = "No new job postings today."
    else:
        body = f"{len(df)} new job(s) posted today:\n\n" + "\n".join(df['title'].tolist())

    msg = EmailMessage()
    msg['Subject'] = f"Eli Lilly Workday Jobs Report – {datetime.now().strftime('%Y-%m-%d')}"
    msg['From'] = 'bdev1238@gmail.com'
    msg['To'] = "bdev1238@gmail.com"
    msg.set_content(body)

    # Attach CSV if there are new postings
    if not df.empty:
        csv_data = df.to_csv(index=False)
        msg.add_attachment(csv_data, filename="workday_jobs_today.csv", subtype="csv")

    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as smtp:
        smtp.login('bdev1238@gmail.com', 'macw dblk fqmc qldy')
        smtp.send_message(msg)

# Call this after your DataFrame is ready:
send_email_report(today_jobs(POST_url,ind_job_url, payload))

# %%
from urllib.request import Request, urlopen, HTTPError
import os
import json
from multiprocessing import Process, Array
import sys
import util
import requests
import pandas as pd
import numpy as np

## to find this, right click and 'inspect element' on the workday page in your browser. from there, navigate to the network tab
## and ctrl + r to refresh the page. you should see a whole bunch of requests come in. sort by Fetch/XHR and click through them until you see one 
## that has a Request Method: of POST instead of GET and it has a request URL and payload that makes sense
POST_url = "https://lilly.wd5.myworkdayjobs.com/wday/cxs/lilly/LLY/jobs"
ind_job_url = "https://lilly.wd5.myworkdayjobs.com/en-US/LLY/details/"
payload = {"appliedFacets": {}, "limit": 20, "offset": 0, "searchText": ""}


url = POST_url
payload = payload
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0"
}

r = requests.post(url, json=payload, headers=headers)

offsets = np.arange(0, r.json()['total'], 20)
jobs = []
for offset in offsets:

    url = POST_url
    payload['offset'] = float(offset)
    payload = payload
    headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0"
    }


    r = requests.post(url, json=payload, headers=headers)
    data = r.json()
    print(data)
    for job in data["jobPostings"]:
        jobs.append({
            "title": job.get("title"),
            "location": job.get("locationsText", ""),
            "postedOn": job.get("postedOn", ""),
            "url": ind_job_url+ job['externalPath'].split('/')[-1]
            })
# Out:
# {'total': 906, 'jobPostings': [{'title': 'Social Content Producer', 'externalPath': '/job/US-Indianapolis-IN/Social-Content-Producer_R-95701-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted Today', 'bulletFields': ['R-95701']}, {'title': 'Sr. Manager - TSMS Validation', 'externalPath': '/job/Italy-Sesto-Fiorentino/Sr-Manager---TSMS-Validation_R-95073-1', 'locationsText': 'Italy, Sesto Fiorentino', 'postedOn': 'Posted Today', 'bulletFields': ['R-95073']}, {'title': 'Associate Director - Parenteral Operations Expansion', 'externalPath': '/job/US-Pleasant-Prairie-WI/Associate-Director---Parenteral-Operations-Expansion_R-94297-1', 'locationsText': '2 Locations', 'postedOn': 'Posted Today', 'bulletFields': ['R-94297']}, {'title': 'Business Integrator / Business Analyst GSC Logistics', 'externalPath': '/job/US-Indianapolis-IN/Business-Integrator---Business-Analyst-GSC-Logistics_R-95849-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted Today', 'bulletFields': ['R-95849']}, {'title': 'Senior Principal Scientist – Sterility Assurance - Technical Services/Manufacturing Science (m/w/d)', 'externalPath': '/job/Germany-Alzey/Senior-Principal-Scientist---Sterility-Assurance---Technical-Services-Manufacturing-Science--m-w-d-_R-93131-2', 'locationsText': 'Germany, Alzey', 'postedOn': 'Posted Today', 'bulletFields': ['R-93131']}, {'title': 'Supervisor - Production Operations Lilly Medicine Foundry', 'externalPath': '/job/US-Lebanon-IN/Supervisor---Production-Operations-Lilly-Medicine-Foundry_R-94237-1', 'locationsText': 'US, Lebanon IN', 'postedOn': 'Posted Today', 'bulletFields': ['R-94237']}, {'title': 'Technician – QC Lab - Lebanon', 'externalPath': '/job/US-Lebanon-IN/Technician---QC-Lab---Lebanon_R-96106-1', 'locationsText': 'US, Lebanon IN', 'postedOn': 'Posted Today', 'bulletFields': ['R-96106']}, {'title': 'Process Technician - Filling/Formulation Nights', 'externalPath': '/job/US-Research-Triangle-Park-NC/Process-Technician---Filling-Formulation-Nights_R-96205-1', 'locationsText': 'US: Research Triangle Park NC', 'postedOn': 'Posted Today', 'bulletFields': ['R-96205']}, {'title': 'Sr. Director - Commissioning and Qualification', 'externalPath': '/job/US-Indianapolis-IN/Commissioning-and-Qualification-Director_R-89376', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted Today', 'bulletFields': ['R-89376']}, {'title': 'Affiliate Pharmacovigilance Manager', 'externalPath': '/job/Brazil-So-Paulo/Affiliate-Pharmacovigilance-Manager_R-96045-1', 'locationsText': 'Brazil, São Paulo', 'postedOn': 'Posted Today', 'bulletFields': ['R-96045']}, {'title': 'Senior Manager - QC', 'externalPath': '/job/US-Indianapolis-IN/Senior-Manager---QC_R-95034-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted Today', 'bulletFields': ['R-95034']}, {'title': 'Associate, Clinical Regulatory Scientist', 'externalPath': '/job/Ireland-Cork/Associate--Clinical-Regulatory-Scientist_R-96046', 'locationsText': 'Ireland, Cork', 'postedOn': 'Posted Today', 'bulletFields': ['R-96046']}, {'title': 'Medical Science Liaison', 'externalPath': '/job/Czech-Republic-Remote/Medical-Science-Liaison_R-96125-1', 'locationsText': 'Czech Republic, Remote', 'postedOn': 'Posted Today', 'bulletFields': ['R-96125']}, {'title': 'Parenteral Operational Readiness Project Manager  (m/w/d)', 'externalPath': '/job/Germany-Alzey/Parenteral-Operational-Readiness-Project-Manager---m-w-d-_R-90548', 'locationsText': 'Germany, Alzey', 'postedOn': 'Posted Today', 'bulletFields': ['R-90548']}, {'title': 'Senior Principal Engineer - Automation Engineering – Systems and Digital Integration', 'externalPath': '/job/US-Lebanon-IN/Senior-Principal-Engineer---Automation-Engineering---Systems-and-Digital-Integration_R-92053-2', 'locationsText': '2 Locations', 'postedOn': 'Posted Today', 'bulletFields': ['R-92053']}, {'title': 'Associate Director - Database Platform Services', 'externalPath': '/job/India-Hyderabad/Associate-Director---Database-Platform-Services_R ...
# {'total': 0, 'jobPostings': [{'title': 'Ingeniero Senior de Robótica', 'externalPath': '/job/ES-Alcobendas/Ingeniero-Senior-de-Robtica_R-94842-1', 'locationsText': 'ES: Alcobendas', 'postedOn': 'Posted Today', 'bulletFields': ['R-94842']}, {'title': 'Senior Director – Data Science and ML Engineering/ Operations', 'externalPath': '/job/India-Bengaluru/Senior-Director---Data-Science-and-ML-Engineering--Operations_R-95388-1', 'locationsText': 'India, Bengaluru', 'postedOn': 'Posted Today', 'bulletFields': ['R-95388']}, {'title': 'Oncology Education Associate', 'externalPath': '/job/Australia-Victoria/Oncology-Education-Associate_R-96090', 'locationsText': 'Australia, Victoria', 'postedOn': 'Posted Today', 'bulletFields': ['R-96090']}, {'title': 'Next Gen Tech Delivery Transformation SME', 'externalPath': '/job/India-Hyderabad/Next-Gen-Tech-Delivery-Transformation-SME_R-90136-1', 'locationsText': 'India, Hyderabad', 'postedOn': 'Posted Today', 'bulletFields': ['R-90136']}, {'title': 'Test Automation Lead', 'externalPath': '/job/India-Hyderabad/Test-Automation-Lead_R-90102-1', 'locationsText': 'India, Hyderabad', 'postedOn': 'Posted Today', 'bulletFields': ['R-90102']}, {'title': 'Associate - CDS', 'externalPath': '/job/India-Bengaluru/Associate---CDS_R-65649', 'locationsText': 'India, Bengaluru', 'postedOn': 'Posted Today', 'bulletFields': ['R-65649']}, {'title': 'Associate - Veterinary Technician', 'externalPath': '/job/US-Indianapolis-IN/Associate---Veterinary-Technician_R-95329-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted Today', 'bulletFields': ['R-95329']}, {'title': '(Sr) Associate- MI', 'externalPath': '/job/Korea-Seoul/XMLNAME--Sr--Associate--MI_R-95881', 'locationsText': 'Korea, Seoul', 'postedOn': 'Posted Today', 'bulletFields': ['R-95881']}, {'title': 'Associate Director - Data Integration Services', 'externalPath': '/job/India-Hyderabad/Associate-Director---Data-Integration-Services_R-92453', 'locationsText': 'India, Hyderabad', 'postedOn': 'Posted Yesterday', 'bulletFields': ['R-92453']}, {'title': 'Associate Director - LEM Operations', 'externalPath': '/job/US-Indianapolis-IN/Associate-Director---LEM-Operations_R-93569-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-93569']}, {'title': 'Associate Director - Clinical Central Services & Innovation', 'externalPath': '/job/US-Indianapolis-IN/Associate-Director---Clinical-Central-Services---Innovation_R-95559-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-95559']}, {'title': 'Filling Lead Operator (Nights)', 'externalPath': '/job/US-Pleasant-Prairie-WI/Filling-Lead-Operator--Nights-_R-93600-1', 'locationsText': 'US, Pleasant Prairie WI', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-93600']}, {'title': 'Hematology Medical Science Liaison', 'externalPath': '/job/Mexico-Monterrey/Hemtaology-Medical-Science-Liaison_R-95990-1', 'locationsText': 'Mexico, Monterrey', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-95990']}, {'title': 'Lead Engineering Technician - Third Shift (10 PM - 6:30 AM)', 'externalPath': '/job/US-Indianapolis-IN/Lead-Engineering-Technician---Third-Shift--10-PM---6-30-AM-_R-91851', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-91851']}, {'title': 'Associate Director - Project Engineering and CQV', 'externalPath': '/job/US-Indianapolis-IN/Associate-Director---Project-Engineering-and-CQV_R-92793-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-92793']}, {'title': 'Project Manager – Project Initiation Team', 'externalPath': '/job/US-Indianapolis-IN/Project-Manager---Project-Initiation-Team_R-94445-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-94445']}, {'title': 'Associate Director - Biologics Operations – Lilly Medicine Foundry', 'externalPath': '/job/US-Lebanon-IN/Associate-Director--- ...
# {'total': 0, 'jobPostings': [{'title': 'Specialist - Quality Assurance für Statistische Sortierung (m/w/d)', 'externalPath': '/job/Germany-Alzey/Specialist---Quality-Assurance-fr-Statistische-Sortierung--m-w-d-_R-95003', 'locationsText': 'Germany, Alzey', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-95003']}, {'title': 'Technician - Quality Assurance - Parenteral (m/w/d)', 'externalPath': '/job/Germany-Alzey/Quality-Assurance-Technician---Parenteral--m-w-d-_R-95004', 'locationsText': 'Germany, Alzey', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-95004']}, {'title': 'Senior Quality Associate, Parenteral  (m/w/d)', 'externalPath': '/job/Germany-Alzey/Senior-Scientist--Quality-Assurance_R-83562-2', 'locationsText': 'Germany, Alzey', 'postedOn': 'Posted 3 Days Ago', 'bulletFields': ['R-83562']}, {'title': 'Senior Sales Consultant – Hematology (Western Canada)', '
# {'total': 0, 'jobPostings': [{'title': 'Associate-Sr. Associate-Manager - Website Measurement and Tagging Lead', 'externalPath': '/job/US-Indianapolis-IN/Associate-Sr-Associate-Manager---Website-Measurement-and-Tagging-Lead_R-94805', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-94805']}, {'title': 'Automation Engineer', 'externalPath': '/job/US-Lebanon-IN/Automation-Engineer_R-95525-1', 'locationsText': 'US, Lebanon IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95525']}, {'title': 'HPC Platform Engineer', 'externalPath': '/job/US-Indianapolis-IN/HPC-Platform-Engineer_R-95581-2', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95581']}, {'title': 'Bioprocess Scientist - Advanced Therapies Manufacturing', 'externalPath': '/job/US-Lebanon-IN/Bioprocess-Scientist---Advanced-Therapies-Manufacturing_R-95594-2', 'locationsText': 'US, Lebanon IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95594']}, {'title': 'Principal Computational Statistician', 'externalPath': '/job/US-Branchburg-NJ/Principal-Computational-Statistician_R-89763-1', 'locationsText': 'US, Branchburg NJ', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-89763']}, {'title': 'Quality Assurance Complaints Representative', 'externalPath': '/job/US-Indianapolis-IN/Quality-Assurance-Complaints-Representative_R-95815-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95815']}, {'title': 'Associate Vice President - Global Facilities Delivery Projects', 'externalPath': '/job/US-Indianapolis-IN/Associate-Vice-President---Global-Facilities-Delivery-Projects_R-93916-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-93916']}, {'title': 'Sr. Manager - Global Cyber - Tactical Defense Operations', 'externalPath': '/job/Ireland-Cork/Sr-Manager---Global-Cyber---Tactical-Defense-Operations_R-95499-1', 'locationsText': 'Ireland, Cork', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95499']}, {'title': 'Senior/Principal Process Engineer', 'externalPath': '/job/US-Lebanon-IN/Senior-Principal-Process-Engineer_R-95524-1', 'locationsText': 'US, Lebanon IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95524']}, {'title': 'Associate Territory Manager - Pharmaceutical Sales - Cardiometabolic Health', 'externalPath': '/job/US-Valparaiso-IN/Associate-Territory-Manager---Pharmaceutical-Sales---Cardiometabolic-Health_R-94711-1', 'locationsText': 'US, Valparaiso IN', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-94711']}, {'title': 'Operator - Medical Device Assembly-5', 'externalPath': '/job/US
ümessili (Onkoloji)', 'externalPath': '/job/Turkey-Remote/Tbbi-Sat-Mmessili--Onkoloji-_R-95793', 'locationsText': 'Turkey, Remote', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95793']}, {'title': 'Associate-QA', 'externalPath': '/job/KR-Seoul/Associate-QA_R-95669-1', 'locationsText': 'KR: Seoul', 'postedOn': 'Posted 6 Days Ago', 'bulletFields': ['R-95669']}, {'title': 'Security Ops Engineer - Privileged Access Management & Identity Governance and Administration', 'externalPath': '/job/Malaysia-Petaling-Jaya/Security-Ops-Engineer---Privileged-Access-Management---Identity-Governance-and-Administration_R-95171-4', 'locationsText': 'Malaysia, Petaling J ...
# {'total': 0, 'jobPostings': [{'title': 'Sr. Principal - Clinical Study Build Programmer - eDC', 'externalPath': '/job/US-Indianapolis-IN/Sr-Principal---Clinical-Study-Build-Programmer---eDC_R-95735', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-95735']}, {'title': 'Advisor - Protein & CAR Construct Engineering', 'externalPath': '/job/US-San-Diego-CA/Advisor---Protein---CAR-Construct-Engineering_R-95529-1', 'locationsText': 'US, San Diego CA', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-95529']}, {'title': 'Clinical Research Physician – Incretins', 'externalPath': '/job/US-Indianapolis-IN/Clinical-Research-Physician---Incretins_R-64932', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-64932']}, {'title': 'Sr. Principal Process Engineer - Small Molecule/Startup', 'externalPath': '/job/US-Indianapolis-IN/ADN-Ramp-Team-Consultant-Engineer_R-81193-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-81193']}, {'title': 'Sr. Principal Process Engineer - Peptide Synthesis/Startup', 'externalPath': '/job/US-Indianapolis-IN/Sr-Principal-Process-Engineer---ADN-Ramp-Team_R-81192', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-81192']}, {'title': 'Associate Director - Device Development QA', 'externalPath': '/job/US-Indianapolis-IN/Associate-Director---Device-Development-QA_R-95411-2', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-95411']}, {'title': 'Scientific Director - Sustainable Peptide Process Chemistry – SMDD', 'externalPath': '/job/US-Indianapolis-IN/Scientific-Director---Sustainable-Peptide-Process-Chemistry---SMDD_R-95637-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-95637']}, {'title': 'Lead Operator - Warehouse Ops- Night Shift', 'externalPath': '/job/US-Indianapolis-IN/Lead-Operator---Warehouse-Ops--Night-Shift_R-95711-1', 'locationsText': 'US, Indianapolis IN', 'postedOn': 'Posted 7 Days Ago', 'bulletFields': ['R-95711']}, {'title': 'Trial Capabilities Associate - German Speaking', 'externalPath': '/job/Ireland-Cork/Trial-Capabilities-Associate---German-Speaking_R-95458-1', 'location
# {'total': 0, 'jobPostings': [{'title': '‘Opportunistic’ HR talent recruitment at Lilly (Associate/Manager/Sr. manager担当/担当課長/課長) / Kobe', 'externalPath': '/job/Japan-Kobe-office/XMLNAME--Opportunistic--HR-talent-recruitment-at-Lilly--Associate-Manager-Sr-manager------Kobe_R-58409-75', 'locationsText': 'Japan, Kobe office', 'postedOn': 'Posted 30+ Days Ago', 'bulletFields': ['R-58409']}, {'title': '<マーケティング本部> Consumer Experience and Innovation Team, Marketing “Talent Recruiting”\u3000Sr.Manager/課長/Kobe', 'externalPath': '/job/Japan-Kobe-office/XMLNAME----Consumer-Experience-and-Innovation-Team--Marketing--Talent-Recruiting--SrManager--Kobe_R-46640', 'locationsText': 'Japan, Kobe office', 'postedOn': 'Posted 30+ Days Ago', 'bulletFields': ['R-46640']}, {'title': '＜研究開発・メディカルアフェアーズ統括本部＞/Japan Data Sciences - Data Strategist Lead/Scientist/ Senior Scientist / Principal Scientist/ Sr. Principal Scientist/神戸本社・東京支社', 'externalPath': '/job/Japan-Kobe-office/XMLNAME-----Japan-Data-Sciences---Data-Strategist-Lead-Scientist--Senior-Scientist---Principal-Scientist--Sr-Principal-Scientist--_R-64539-56', 'locationsText': 'Japan, Kobe office', 'postedOn': 'Posted 30+ Days Ago', 'bulletFields': ['R-64539']}, {'title': '＜研究開発・ﾒﾃﾞｨｶﾙｱﾌｪｱｰｽﾞ統括本部＞Statistical Analyst\u3000/ Statistician , Senior Statistician, Principal Statistician /Kobe HQ・Tokyo Office', 'externalPath': '/job/Japan-Kobe-office/XMLNAME-----------------Statistical-Analyst---Statistician---Senior-Statistician--Principal-Statistician--Kobe-HQ-Tokyo-Office_R-67970-4', 'locationsText': 'Japan, Kobe office', 'postedOn': 'Posted 30+ Days Ago', 'bulletFields': ['R-67970']}, {'title': '【障がい者採用：契約社員】リスキリングプログラム（最長2年）/神戸本社', 'externalPath': '/job/Japan-Kobe-office/XMLNAME--------_R-353-16', 'locationsText': '2 Locations', 'postedOn': 'Posted 30+ Days Ago', 'bulletFields': ['R-353']}, {'title': '【障がい者採用：正社員】本社スタッフ部門(人事・IT・財務経理・マーケティング・その他)/担当・担当課長・専門課長/神戸本社', 'externalPath': '/job/Japan-Kobe-office/XMLNAME------IT--------_R-349-70', 'locationsText': 'Japan, Kobe office', 'postedOn': 'Posted 30+ Days Ago', 'bulletFields': ['R-349']}], 'facets': [], 'userAuthenticated': False}

# %%
pd.DataFrame(jobs)['postedOn']
# Out:
# 0             Posted Today
# 1             Posted Today
# 2             Posted Today
# 3             Posted Today
# 4             Posted Today
#               ...
# 901    Posted 30+ Days Ago
# 902    Posted 30+ Days Ago
# 903    Posted 30+ Days Ago
# 904    Posted 30+ Days Ago
# 905    Posted 30+ Days Ago
# Name: postedOn, Length: 906, dtype: object
